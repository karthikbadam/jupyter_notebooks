# %%
import wikia
import json
import sys
import requests

from httpstream import get

from bs4 import BeautifulSoup

soup = BeautifulSoup

root_url = 'http://marvel.wikia.com'

marvelArticles = requests.get('http://marvel.wikia.com/api/v1/Articles/Top')

itemsList = json.loads(marvelArticles.text).get('items')

#print (itemsList)

x = []
y = [] 

for item in itemsList:
    
    itemTitle = item.get('title')
    
    itemUrl = root_url + item.get('url')
    
    #print (itemTitle + ":" + itemUrl)
    
    # get links to these top pages
    itemHtml = requests.get(itemUrl)
    
    soupPage = BeautifulSoup(itemHtml.text)
    
    itemLinks = soupPage.find_all("a")
    
    count = 0
    
    for itemLink in itemLinks:
        
        count+=1    
    
    x.append(itemTitle)
    y.append(count)
       
    print itemTitle + " has {} links".format(count)
# Out:
# Deadpool (Wade Wilson) has 287 links
# Characters has 393 links
# Henry Pym (Earth-616) has 298 links
# Scott Lang (Earth-616) has 297 links
# Infinity Gems has 386 links
# Hope Pym (Earth-982) has 315 links
# Ant-Man has 429 links
# Spider-Man (Peter Parker) has 325 links
# List of Avengers members has 463 links
# J'son (Earth-616) has 330 links
# Wolverine (James "Logan" Howlett) has 309 links
# Iron Man (Anthony "Tony" Stark) has 259 links
# Captain America (Steven Rogers) has 256 links
# TheBlueRogue/20 Most Fantastic Superpowers of All Time has 137 links
# Peter Quill (Earth-616) has 235 links
# Thanos (Earth-616) has 268 links
# Hulk (Robert Bruce Banner) has 300 links
# Janet van Dyne (Earth-616) has 275 links
# Thor (Thor Odinson) has 295 links
# Hank Pym has 235 links
# En Sabah Nur (Earth-616) has 253 links
# One-Above-All (Multiverse) has 279 links
# Victor von Doom (Earth-616) has 283 links
# Secret Wars has 341 links
# Scott Lang has 410 links
# Darren Cross (Earth-616) has 320 links
# Spider-Man has 235 links
# Cassandra Lang (Earth-616) has 289 links
# Microverse has 271 links
# Earth-199999 has 451 links
# Earth-616 has 314 links
# Civil War (Event) has 296 links
# Strength Scale has 604 links
# Galactus (Earth-616) has 255 links
# Pym Particles has 326 links
# Power Grid has 194 links
# Ant-Man (film) has 255 links
# Yellowjacket has 263 links
# Spider-Man's Suits has 234 links
# Everett Ross (Earth-616) has 323 links
# Stephen Strange (Earth-616) has 280 links
# Iron Man Armor has 188 links
# Death (Earth-616) has 249 links
# Motion Picture Funnies Weekly Vol 1 1 has 239 links
# Wanda Maximoff (Earth-616) has 271 links
# Katherine Pryde (Earth-616) has 273 links
# Matthew Murdock (Earth-616) has 268 links
# Avengers (Earth-616) has 528 links
# Living Tribunal (Multiverse) has 241 links
# Spider-Verse has 560 links
# Eugene Thompson (Earth-616) has 262 links
# Mutant Power Level Classification has 502 links
# Mitch Carson (Earth-616) has 410 links
# Beyonders has 239 links
# Carol Danvers (Earth-616) has 282 links
# Illuminati (Earth-616) has 248 links
# Guardians of the Galaxy (Earth-616) has 295 links
# Ultron (Earth-616) has 256 links
# James Buchanan Barnes (Earth-616) has 240 links
# Vision (Earth-616) has 311 links
# T'Challa (Earth-616) has 296 links
# Daisy Johnson (Earth-616) has 288 links
# Scott Summers (Earth-616) has 286 links
# Wasp has 235 links
# Iron Spider Armor has 375 links
# Adam Warlock (Earth-616) has 255 links
# Jean Grey (Earth-616) has 291 links
# Omega Level Mutants has 183 links
# Female Characters has 365 links
# Celestials (Race) has 234 links
# Infinity Gauntlet (Item) has 371 links
# Ant-Man Villains has 154 links
# Natalia Romanova (Earth-616) has 286 links
# Clinton Barton (Earth-616) has 306 links
# Eric O'Grady (Earth-616) has 242 links
# Cindy Moon (Earth-616) has 236 links
# Homosexual Characters has 155 links
# Franklin Richards (Earth-616) has 260 links
# Gwendolyne Stacy (Earth-65) has 386 links
# Height Scale has 776 links
# Nathan Summers (Earth-616) has 306 links
# Miles Morales (Earth-1610) has 253 links
# Max Eisenhardt (Earth-616) has 281 links
# Robert Reynolds (Earth-616) has 220 links
# Iron Man has 234 links
# Elizabeth Braddock (Earth-616) has 304 links
# Loki Laufeyson (Earth-616) has 271 links
# Anti-Venom (Klyntar) (Earth-616) has 211 links
# Giant-Man has 433 links
# Deadpool has 232 links
# Ant-Man Suit has 329 links
# Sabretooth (Victor Creed) has 265 links
# Hulk has 230 links
# Hope Summers (Earth-616) has 273 links
# Jessica Jones (Earth-616) has 248 links
# Inhumans (Inhomo supremis) has 289 links
# Iron Man Armor Model 51 has 230 links
# Blackagar Boltagon (Earth-616) has 267 links
# Earth-1610 has 243 links
# Death of Spider-Man has 280 links
# Beyonder (Earth-616) has 245 links
# Thane (Thanos' son) (Earth-616) has 271 links
# Old Man Logan has 211 links
# X-Men (Earth-616) has 573 links
# All-New, All-Different Marvel has 190 links
# Reed Richards (Earth-1610) has 241 links
# Thaddeus Ross (Earth-616) has 228 links
# Reed Richards (Earth-616) has 254 links
# Jane Foster (Earth-616) has 267 links
# Pietro Maximoff (Earth-616) has 276 links
# Eternity (Earth-616) has 248 links
# Captain America has 232 links
# Horsemen of Apocalypse (Earth-616) has 387 links
# Jamie/Marvel Database's 10th Anniversary has 131 links
# Darren Cross has 261 links
# Deadpool Kills the Marvel Universe Vol 1 1 has 249 links
# Johnathon Blaze (Earth-616) has 223 links
# Klyntar has 222 links
# Akihiro (Earth-616) has 262 links
# Spartoi has 191 links
# Venom has 233 links
# Phoenix Force (Earth-616) has 282 links
# Peter Parker (Kaine) (Earth-616) has 254 links
# Namor McKenzie (Earth-616) has 291 links
# Characters by Power has 151 links
# Thor has 244 links
# Otto Octavius (Earth-616) has 266 links
# Scott Lang (Earth-199999) has 326 links
# Norrin Radd (Earth-616) has 250 links
# Ororo Munroe (Earth-616) has 286 links
# Frank Castle (Earth-616) has 270 links
# Charles Xavier (Earth-616) has 289 links
# Apocalypse has 232 links
# Raven Darkholme (Earth-616) has 270 links
# Emma Frost (Earth-616) has 281 links
# Wanda Wilson (Earth-3010) has 225 links
# Mjolnir has 276 links
# Laura Kinney (Earth-616) has 288 links
# Venom (Klyntar) (Earth-616) has 216 links
# Henry Gyrich (Earth-616) has 265 links
# Wolverine has 235 links
# William Kaplan (Earth-616) has 278 links
# Rogue (Anna Marie) (Earth-616) has 273 links
# Darren Cross (Earth-199999) has 335 links
# Samuel Wilson (Earth-616) has 275 links
# Young Avengers (Earth-616) has 300 links
# Comics has 390 links
# Edward Brock (Earth-616) has 236 links
# Arthur Douglas (Earth-616) has 251 links
# Warren Worthington III (Earth-616) has 288 links
# Jonathan Storm (Earth-616) has 305 links
# Neena Thurman (Earth-616) has 243 links
# Benjamin Grimm (Earth-616) has 259 links
# Eleanor Camacho (Earth-616) has 261 links
# Peter Parker (Earth-96283) has 200 links
# Spider-Man Unlimited (video game) has 306 links
# Nicholas Fury (Earth-616) has 267 links
# Norman Osborn (Earth-616) has 274 links
# Kamala Khan (Earth-616) has 252 links
# Kree has 266 links
# Groot (Earth-616) has 222 links
# Ant-Man's Ants has 369 links
# Remy LeBeau (Earth-616) has 254 links
# Wilson Fisk (Earth-616) has 237 links
# Ms. Marvel has 232 links
# Mar-Vell (Earth-616) has 230 links
# Susan Storm (Earth-616) has 275 links
# Jessica Drew (Earth-616) has 267 links
# Luke Cage (Earth-616) has 298 links
# Peter Parker (Earth-1610) has 270 links
# Richard Jones (Earth-616) has 263 links
# Arno Stark (Earth-616) has 257 links
# Captain America's Shield has 278 links
# Daniel Rand (Earth-616) has 269 links
# Psylocke has 249 links
# Squadron Supreme (Earth-712) has 302 links
# Celestials has 137 links
# Vanessa Carlysle (Earth-616) has 243 links
# Superior Iron Man Vol 1 1 has 208 links
# Iron Man (film) has 293 links
# Illyana Rasputina (Earth-616) has 274 links
# Hope van Dyne (Earth-199999) has 316 links
# Gamora Zen Whoberi Ben Titan (Earth-7528) has 256 links
# Jennifer Walters (Earth-616) has 274 links
# Ghost Rider has 225 links
# Nathaniel Essex (Earth-616) has 237 links
# Odin Borson (Earth-616) has 288 links
# Kurt Wagner (Earth-616) has 276 links
# Zarda (Earth-31916) has 311 links
# Ronan (Earth-616) has 277 links
# Henry Pym Jr. (Earth-982) has 204 links
# Nathaniel Grey (Earth-295) has 318 links
# Felicia Hardy (Earth-616) has 233 links
# Daredevil has 231 links
# Piotr Rasputin (Earth-616) has 316 links
# Elizabeth Ross (Earth-616) has 239 links
# Shiklah (Earth-616) has 233 links
# Battleworld (Latverion) has 303 links
# Henry Pym (Earth-199999) has 316 links
# Cassandra Lang (Earth-982) has 195 links
# Incursion has 265 links
# Adamantium has 349 links
# Iron Man Armor Model 38 has 212 links
# Robert Drake (Earth-616) has 307 links
# Avengers has 236 links
# En Sabah Nur (Evan Sabahnur) (Earth-616) has 236 links
# Gwendolyne Stacy (Earth-616) has 232 links
# Gabriel Summers (Earth-616) has 260 links
# Cassie Lang has 494 links
# Nathaniel Richards (Kang) (Earth-6311) has 274 links
# Cletus Kasady (Earth-616) has 261 links
# Tony Masters (Earth-616) has 256 links
# Owen Reece (Earth-616) has 218 links
# Miguel O'Hara (Earth-928) has 251 links
# Hercules (Earth-616) has 286 links
# Amazing Spider-Man Vol 1 has 228 links
# Alexander Summers (Earth-616) has 286 links
# Daisy Johnson (Earth-199999) has 237 links
# Brian Braddock (Earth-616) has 287 links
# Henry McCoy (Earth-616) has 276 links
# Extremis virus has 288 links
# Cain Marko (Earth-616) has 276 links
# Aldrif Odinsdottir (Earth-616) has 261 links
# Simon Williams (Earth-616) has 228 links
# Jubilation Lee (Earth-616) has 259 links
# Big Hero Six (Earth-616) has 317 links
# Captain Marvel has 229 links
# Thor Odinson (Ragnarok) (Earth-616) has 252 links
# Skrulls has 282 links
# Spider-Man Villains has 502 links
# Katherine Bishop (Earth-616) has 284 links
# Hope Pym has 243 links
# Mephisto (Earth-616) has 230 links
# Week 30, 2015 has 179 links
# Dorrek VIII (Earth-616) has 259 links
# Amadeus Cho (Earth-616) has 288 links
# Secret Wars Vol 1 5 has 173 links
# Homo superior has 348 links
# Spider-Army (Peter Parker's) (Multiverse) has 459 links
# Doctor Doom has 230 links
# Henry Pym (Earth-982) has 210 links
# Zarda Shelton (Earth-712) has 245 links
# Richard Rider (Earth-616) has 237 links
# Taneleer Tivan (Earth-616) has 242 links

# %%
import plotly.plotly as py  
py.sign_in('karthikbadam', 'mevafrzvrl')

# (*) Useful Python/Plotly tools
import plotly.tools as tls   

# (*) Graph objects to piece together plots
from plotly.graph_objs import *

links = Scatter(
    x=x,
    y=y,
    fill='tozeroy'
)
py.iplot([links], filename = 'area')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~karthikbadam/50.embed" height="525" width="100%"></iframe>
